# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv("F:/Masters/Semester 3/rekognition/dataset1.csv", delimiter=",")

# %%
dataset.head()
# Out:
#    Unnamed: 0                  Name   Label  Confidence        City  Country  \
# 0           0  1f0bcba2eff20f69.jpg    Food    96.00148  Drumcondra  Ireland
# 1           1  1f0bcba2eff20f69.jpg   Pasta    96.00148  Drumcondra  Ireland
# 2           2  1f0bcba2eff20f69.jpg  Noodle    96.00148  Drumcondra  Ireland
# 3           3  1f0bcba2eff20f69.jpg   Human    85.54834  Drumcondra  Ireland
# 4           4  1f0bcba2eff20f69.jpg  Person    85.54834  Drumcondra  Ireland
#
#    Longitude   Latitude   Category MainCategory  LabelScore  CategoryScore  \
# 0  -8.445614  51.888509       Food    Transport         215              2
# 1  -8.445614  51.888509       Food    Transport         377              2
# 2  -8.445614  51.888509       Food    Transport         359              2
# 3  -8.445614  51.888509  Transport    Transport         273              3
# 4  -8.445614  51.888509  Transport    Transport         385              3
#
#    MainCategoryScore
# 0                  3
# 1                  3
# 2                  3
# 3                  3
# 4                  3

# %%
X = dataset.iloc[:, :-1].values  
y = dataset.iloc[:, 9].values

# %%
X
# Out:
# array([[0, '1f0bcba2eff20f69.jpg', 'Food', ..., 'Transport', 215, 2],
#        [1, '1f0bcba2eff20f69.jpg', 'Pasta', ..., 'Transport', 377, 2],
#        [2, '1f0bcba2eff20f69.jpg', 'Noodle', ..., 'Transport', 359, 2],
#        ...,
#        [3349, '066bffc47c143942.jpg', 'Clothing', ..., 'Clothing', 121,
#         1],
#        [3350, '066bffc47c143942.jpg', 'Tie', ..., 'Clothing', 538, 1],
#        [3351, '066bffc47c143942.jpg', 'Accessories', ..., 'Clothing', 1,
#         1]], dtype=object)

# %%
y
# Out:
# array(['Transport', 'Transport', 'Transport', ..., 'Clothing', 'Clothing',
#        'Clothing'], dtype=object)

# %%
from sklearn.model_selection import train_test_split  
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)

# %%
from sklearn.preprocessing import StandardScaler  
scaler = StandardScaler()  
scaler.fit(X_train)

X_train = scaler.transform(X_train)  
X_test = scaler.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-65cee51b896e> in <module>
#       1 from sklearn.preprocessing import StandardScaler
#       2 scaler = StandardScaler()
# ----> 3 scaler.fit(X_train)
#       4
#       5 X_train = scaler.transform(X_train)
#
# ~\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py in fit(self, X, y)
#     643         # Reset internal state before fitting
#     644         self._reset()
# --> 645         return self.partial_fit(X, y)
#     646
#     647     def partial_fit(self, X, y=None):
#
# ~\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py in partial_fit(self, X, y)
#     667         X = check_array(X, accept_sparse=('csr', 'csc'), copy=self.copy,
#     668                         warn_on_dtype=True, estimator=self, dtype=FLOAT_DTYPES,
# --> 669                         force_all_finite='allow-nan')
#     670
#     671         # Even in the case of `with_mean=False`, we update the mean anyway
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     525             try:
#     526                 warnings.simplefilter('error', ComplexWarning)
# --> 527                 array = np.asarray(array, dtype=dtype, order=order)
#     528             except ComplexWarning:
#     529                 raise ValueError("Complex data not supported\n"
#
# ~\Anaconda3\lib\site-packages\numpy\core\numeric.py in asarray(a, dtype, order)
#     536
#     537     """
# --> 538     return array(a, dtype, copy=False, order=order)
#     539
#     540
#
# ValueError: could not convert string to float: '164bfbc69af1d544.jpg'

# %%
# Out:
# array(['Food', 'Transport', 'Transport', 'Transport', 'Transport',
#        'Transport', 'Transport', 'Food', 'Food', 'Transport', 'Food',
#        'Transport', 'Food', 'Transport', 'Transport', 'Clothing', 'Food',
#        'Architecture', 'Clothing', 'Transport', 'Food', 'Clothing',
#        'Transport', 'Transport', 'Transport', 'Transport', 'Clothing',
#        'Transport', 'Transport', 'Architecture', 'Transport',
#        'Architecture', 'Transport', 'Transport', 'Clothing', 'Clothing',
#        'Architecture', 'Food', 'Transport', 'Clothing', 'Clothing',
#        'Architecture', 'Architecture', 'Transport', 'Clothing',
#        'Transport', 'Food', 'Food', 'Food', 'Transport', 'Clothing',
#        'Architecture', 'Transport', 'Architecture', 'Clothing', 'Food',
#        'Transport', 'Food', 'Clothing', 'Food', 'Architecture',
#        'Transport', 'Food', 'Clothing', 'Clothing', 'Transport',
#        'Transport', 'Clothing', 'Transport', 'Clothing', 'Clothing',
#        'Transport', 'Transport', 'Transport', 'Architecture',
#        'Architecture', 'Transport', 'Architecture', 'Transport',
#        'Clothing', 'Architecture', 'Transport', 'Transport', 'Clothing',
#        'Food', 'Clothing', 'Food', 'Transport', 'Architecture',
#        'Transport', 'Clothing', 'Clothing', 'Architecture', 'Transport',
#        'Clothing', 'Food', 'Transport', 'Clothing', 'Clothing',
#        'Transport', 'Transport', 'Transport', 'Architecture',
#        'Architecture', 'Architecture', 'Transport', 'Clothing',
#        'Clothing', 'Transport', 'Clothing', 'Architecture', 'Food',
#        'Architecture', 'Transport', 'Architecture', 'Transport',
#        'Clothing', 'Clothing', 'Transport', 'Transport', 'Transport',
#        'Clothing', 'Transport', 'Food', 'Transport', 'Clothing', 'Food',
#        'Clothing', 'Clothing', 'Food', 'Architecture', 'Architecture',
#        'Transport', 'Transport', 'Transport', 'Transport', 'Transport',
#        'Transport', 'Clothing', 'Clothing', 'Food', 'Transport',
#        'Transport', 'Clothing', 'Food', 'Transport', 'Food',
#        'Architecture', 'Transport', 'Clothing', 'Clothing',
#        'Architecture', 'Architecture', 'Architecture', 'Transport',
#        'Transport', 'Architecture', 'Transport', 'Transport', 'Food',
#        'Food', 'Food', 'Transport', 'Architecture', 'Clothing',
#        'Transport', 'Transport', 'Transport', 'Clothing', 'Transport',
#        'Transport', 'Clothing', 'Architecture', 'Transport',
#        'Architecture', 'Food', 'Food', 'Architecture', 'Clothing',
#        'Transport', 'Food', 'Clothing', 'Transport', 'Transport',
#        'Architecture', 'Transport', 'Clothing', 'Architecture',
#        'Clothing', 'Transport', 'Transport', 'Architecture', 'Transport',
#        'Transport', 'Transport', 'Clothing', 'Transport', 'Architecture',
#        'Transport', 'Architecture', 'Transport', 'Clothing', 'Transport',
#        'Food', 'Transport', 'Clothing', 'Food', 'Transport', 'Transport',
#        'Transport', 'Architecture', 'Transport', 'Transport', 'Transport',
#        'Transport', 'Transport', 'Transport', 'Transport', 'Food',
#        'Clothing', 'Transport', 'Transport', 'Architecture', 'Transport',
#        'Transport', 'Clothing', 'Clothing', 'Food', 'Clothing',
#        'Transport', 'Architecture', 'Transport', 'Transport', 'Transport',
#        'Transport', 'Food', 'Transport', 'Food', 'Transport', 'Transport',
#        'Clothing', 'Transport', 'Transport', 'Food', 'Clothing',
#        'Architecture', 'Clothing', 'Architecture', 'Architecture', 'Food',
#        'Architecture', 'Food', 'Food', 'Transport', 'Transport',
#        'Transport', 'Architecture', 'Transport', 'Transport', 'Food',
#        'Clothing', 'Transport', 'Food', 'Clothing', 'Food',
#        'Architecture', 'Transport', 'Food', 'Food', 'Transport',
#        'Transport', 'Transport', 'Transport', 'Clothing', 'Transport',
#        'Architecture', 'Food', 'Transport', 'Transport', 'Clothing',
#        'Clothing', 'Transport', 'Transport', 'Transport', 'Transport',
#        'Architecture', 'Transport', 'Transport', 'Food', 'Transport',
#        'Food', 'Transport', 'Architecture', 'Transport', 'Food',
#        'Architecture', 'Transport', 'Food', 'Food', 'Architecture',
#        'Food', 'Transport', 'Transport', 'Transport', 'Transport',
#        'Transport', 'Architecture', 'Transport', 'Transport',
#        'Architecture', 'Clothing', 'Clothing', 'Transport', 'Food',
#        'Transport', 'Transport', 'Transport', 'Transport', 'Food',
#        'Transport', 'Transport', 'Architecture', 'Clothing', 'Clothing',
#        'Transport', 'Transport', 'Architecture', 'Clothing', 'Clothing',
#        'Transport', 'Clothing', 'Transport', 'Clothing', 'Food',
#        'Transport', 'Food', 'Transport', 'Architecture', 'Food',
#        'Architecture', 'Clothing', 'Architecture', 'Transport', 'Food',
#        'Clothing', 'Clothing', 'Architecture', 'Transport', 'Food',
#        'Transport', 'Architecture', 'Clothing', 'Transport', 'Clothing',
#        'Transport', 'Clothing', 'Clothing', 'Transport', 'Food',
#        'Transport', 'Clothing', 'Transport', 'Clothing', 'Transport',
#        'Transport', 'Transport', 'Food', 'Transport', 'Architecture',
#        'Transport', 'Transport', 'Food', 'Transport', 'Transport',
#        'Transport', 'Architecture', 'Transport', 'Food', 'Transport',
#        'Architecture', 'Transport', 'Food', 'Clothing', 'Architecture',
#        'Clothing', 'Transport', 'Clothing', 'Transport', 'Transport',
#        'Food', 'Transport', 'Transport', 'Transport', 'Transport',
#        'Transport', 'Architecture', 'Clothing', 'Clothing', 'Clothing',
#        'Transport', 'Transport', 'Architecture', 'Architecture',
#        'Architecture', 'Transport', 'Clothing', 'Transport', 'Transport',
#        'Transport', 'Architecture', 'Transport', 'Food', 'Food',
#        'Clothing', 'Architecture', 'Transport', 'Transport', 'Transport',
#        'Transport', 'Food', 'Transport', 'Transport', 'Architecture',
#        'Food', 'Transport', 'Architecture', 'Food', 'Architecture',
#        'Food', 'Food', 'Clothing', 'Clothing', 'Clothing', 'Clothing',
#        'Transport', 'Food', 'Food', 'Transport', 'Architecture', 'Food',
#        'Transport', 'Food', 'Clothing', 'Food', 'Food', 'Transport',
#        'Architecture', 'Transport', 'Transport', 'Clothing', 'Transport',
#        'Clothing', 'Architecture', 'Clothing', 'Architecture',
#        'Architecture', 'Clothing', 'Clothing', 'Clothing', 'Transport',
#        'Transport', 'Transport', 'Architecture', 'Transport', 'Food',
#        'Transport', 'Transport', 'Transport', 'Transport', 'Transport',
#        'Transport', 'Transport', 'Clothing', 'Clothing', 'Clothing',
#        'Food', 'Clothing', 'Transport', 'Transport', 'Food', 'Food',
#        'Transport', 'Transport', 'Architecture', 'Food', 'Clothing',
#        'Clothing', 'Architecture', 'Transport', 'Transport', 'Transport',
#        'Architecture', 'Transport', 'Transport', 'Transport', 'Food',
#        'Transport', 'Architecture', 'Food', 'Architecture', 'Transport',
#        'Transport', 'Architecture', 'Clothing', 'Food', 'Food',
#        'Architecture', 'Food', 'Food', 'Transport', 'Food', 'Transport',
#        'Architecture', 'Transport', 'Transport', 'Architecture',
#        'Clothing', 'Clothing', 'Transport', 'Food', 'Food', 'Clothing',
#        'Clothing', 'Clothing', 'Transport', 'Transport', 'Clothing',
#        'Food', 'Transport', 'Transport', 'Transport', 'Food', 'Clothing',
#        'Food', 'Transport', 'Transport', 'Transport', 'Transport',
#        'Transport', 'Food', 'Clothing', 'Transport', 'Food',
#        'Architecture', 'Food', 'Clothing', 'Transport', 'Food',
#        'Clothing', 'Architecture', 'Food', 'Architecture', 'Transport',
#        'Architecture', 'Transport', 'Clothing', 'Clothing', 'Transport',
#        'Transport', 'Transport', 'Transport', 'Transport', 'Clothing',
#        'Food', 'Transport', 'Architecture', 'Architecture', 'Transport',
#        'Transport', 'Transport', 'Transport', 'Clothing', 'Transport',
#        'Transport', 'Architecture', 'Transport', 'Transport', 'Transport',
#        'Architecture', 'Clothing', 'Architecture', 'Food', 'Clothing',
#        'Food', 'Transport', 'Food', 'Transport', 'Transport', 'Food',
#        'Food', 'Architecture', 'Clothing', 'Transport', 'Clothing',
#        'Transport', 'Architecture', 'Clothing', 'Food', 'Transport',
#        'Food', 'Transport', 'Transport', 'Architecture', 'Architecture',
#        'Clothing', 'Transport', 'Transport', 'Transport', 'Architecture',
#        'Food', 'Clothing', 'Food', 'Transport', 'Clothing',
#        'Architecture', 'Architecture', 'Transport', 'Clothing',
#        'Transport', 'Transport', 'Transport', 'Clothing', 'Transport',
#        'Transport', 'Clothing', 'Clothing', 'Food', 'Transport',
#        'Transport', 'Architecture', 'Clothing', 'Food', 'Transport',
#        'Clothing', 'Transport', 'Clothing', 'Architecture', 'Transport',
#        'Transport', 'Transport', 'Food', 'Transport', 'Transport', 'Food',
#        'Food', 'Food', 'Transport', 'Food', 'Clothing', 'Clothing',
#        'Transport', 'Clothing', 'Transport', 'Clothing', 'Transport',
#        'Architecture', 'Transport', 'Transport', 'Clothing', 'Clothing',
#        'Architecture', 'Architecture', 'Transport', 'Clothing', 'Food',
#        'Clothing', 'Food', 'Clothing', 'Clothing', 'Food', 'Transport'],
#       dtype=object)
