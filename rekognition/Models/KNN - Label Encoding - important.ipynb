# %%
import pandas as pd

# %%
df = pd.read_csv("F:/Masters/Semester 3/thesis/rekognition/Dataset/Cleaning/dataset2.csv", delimiter=",")

# %%
df
# Out:
#       id  first_name      last_name                            email  gender  \
# 0     10    Caldwell        Fewlass               cfewlass9@ehow.com    Male
# 1     11       Drusy        Lanaway               dlanawaya@narod.ru  Female
# 2     12       Trish        Purveys        tpurveysb@theguardian.com  Female
# 3     13      Gardie        Bridges      gbridgesc@deliciousdays.com    Male
# 4     14      Hobard           Budd              hbuddd@hatena.ne.jp    Male
# 5     15      Janina         Bratty                jbrattye@ucla.edu  Female
# 6     16    Danyette         Lesley           dlesleyf@earthlink.net  Female
# 7     17     Sibilla      Lauritzen         slauritzeng@netscape.com  Female
# 8     18     Webster         Arnley         warnleyh@istockphoto.com    Male
# 9     19      Benita          Lante                 blantei@yale.edu  Female
# 10    20      Willie        Westley        wwestleyj@yellowpages.com    Male
# ...

# %%
from sklearn import preprocessing

# %%
l = preprocessing.LabelEncoder()
df['MainCategory'] = l.fit_transform(df['MainCategory'])

l = preprocessing.LabelEncoder()
df['gender'] = l.fit_transform(df['gender'])

l = preprocessing.LabelEncoder()
df['City'] = l.fit_transform(df['City'])

l = preprocessing.LabelEncoder()
df['Country'] = l.fit_transform(df['Country'])

l = preprocessing.LabelEncoder()
df['Profession'] = l.fit_transform(df['Profession'])

# %%
df
# Out:
#       id  first_name      last_name                            email  gender  \
# 0     10    Caldwell        Fewlass               cfewlass9@ehow.com       1
# 1     11       Drusy        Lanaway               dlanawaya@narod.ru       0
# 2     12       Trish        Purveys        tpurveysb@theguardian.com       0
# 3     13      Gardie        Bridges      gbridgesc@deliciousdays.com       1
# 4     14      Hobard           Budd              hbuddd@hatena.ne.jp       1
# 5     15      Janina         Bratty                jbrattye@ucla.edu       0
# 6     16    Danyette         Lesley           dlesleyf@earthlink.net       0
# 7     17     Sibilla      Lauritzen         slauritzeng@netscape.com       0
# 8     18     Webster         Arnley         warnleyh@istockphoto.com       1
# 9     19      Benita          Lante                 blantei@yale.edu       0
# 10    20      Willie        Westley        wwestleyj@yellowpages.com       1
# ...

# %%
df.to_csv("F:/Masters/Semester 3/thesis/rekognition/Dataset/Cleaning/dataset-final.csv", sep=',')
